# %%
a=input("a=");
b=input ("b=");
a=int(a)
b=int(b)

if (a==b):
  print("eqal")
else:
  print("not eqal")

print(a==b)
# Out:
# a=22
# b=22
# eqal
# True

# %%
a=input("a=");
b=input ("b=");
a=int(a)
b=int(b)

print(a>b)
# Out:
# a=22
# b=22
# False

# %%
#2bigger number 1output
a=input("a=");
b=input ("b=");
a=int(a)
b=int(b)

if(a>b):
  print("a is bigger number")
  print(a)
else:
    print("b in bigger number")
    print(b)
# Out:
# a=5
# b=8
# b in bigger number
# 8

# %%
#inrement
a= int (input("a:"))
a+=1
print(a)
# Out:
# a:33
# 34

# %%
a = 5
b = 7
print(a>3 and b <7)
# Out:
# False

# %%
a = 5
b = 7
print(a>3 or b <7)
# Out:
# True

# %%
a = 5
b = 5
print(not a>3 and b <7)
# Out:
# False

# %%
colors = ["black", "white", "blue" , "rade", "green"]

search_colors = input("Enter a color to search: ").lower()

israt = colors.count(search_colors)
if israt > 0:
    print(f"The color '{search_colors}' appears {israt} time(s) in the list.")
else:
    print(f"The color '{search_colors}' is not in the list.")
# Out:
# Enter a color to search: black
# The color 'black' appears 1 time(s) in the list.

# %%
a= [1,2,3]
b= [1,2,3]
print(a is not b)
print(id(a),(b))
# Out:
# True
# 135354138641408 [1, 2, 3]

# %%
a= [1,2,3]
b= [4,4,6]
print(a is not b)
print(id(a),(b))
# Out:
# True
# 135354149879872 [4, 4, 6]

# %%
a= [1,2,3,4,5,]
b= [5,6,7,8,9,]
(a is b)
print(a)
print(b)
# Out:
# [1, 2, 3, 4, 5]
# [5, 6, 7, 8, 9]

# %%
a= [1,2,3,4,5,]
b= [5,6,7,8,9,]
(a is not b)
print(a)
print(b)
# Out:
# [1, 2, 3, 4, 5]
# [5, 6, 7, 8, 9]

# %%
a= [1,2,3,4,5,]
b= [5,6,7,8,9,]
print(a is b)
# Out:
# False

# %%
a= [1,2,3,4,5,]
b= [5,6,7,8,9,]
print(a is not b)
# Out:
# True

# %%
list , tupol, dictonary

# %%
3 not in [1,2,3]
(2,3) in ((1,2),(2,3),(3,5))
# Out:
# True

# %%
#oppratio
a = 10
b = 4
print("a & b =", a & b)

a = 10
b = 4
print("a | b =", a | b)

a = 10
b = 4
print("a ^ b =", a ^ b)

a = 10
b = 4
print("~a =", ~a)

a = 10
b = -10
print("a >> 1 =", a >> 1)
print("b >> 1 =", b >> 1)
# Out:
# a & b = 0
# a | b = 14
# a ^ b = 14
# ~a = -11
# a >> 1 = 5
# b >> 1 = -5

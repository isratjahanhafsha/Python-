# %%
def greet ( Israt ):
  return f"Hello , { Israt }"

# %%
def greet ( Israt ):
  return f"Hello , { Israt }!"
greet=greet ("Israt")
print(greet)
# Out:
# Hello , Israt!

# %%
def calculate_area ( length , width ) :
  return length * width
area = calculate_area (7 , 10)
print ( area )
# Out:
# 70

# %%
import math
print ( math . sqrt (16) )
# Out:
# 4.0

# %%
code = """
def greet(Israt):
    return f"Hello, {Israt}!"

def add(a, b):
    return a + b

def subtract(a, b):
    return a - b
"""
with open('mymodule.py', 'w') as f:
    f.write(code)
import mymodule
print(mymodule.greet("Israt"))
print(mymodule.add(5, 8))
print(mymodule.subtract(10, 6))
# Out:
# Hello, Israt!
# 13
# 4

# %%
#Opening a file in read mode
file=open ("example.txt","r")

#Closing the file
file . close ()
print(My_data)

# %%
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')

# List files in the specified directory
# !ls "/content/drive/My Drive/"

# Define the file path
file_path = "/content/drive/My Drive/example.txt"

try:
# Open and read the file line by line
    with open(file_path, "r") as file:
        for line in file:
            print(line.strip())
except FileNotFoundError:
# Handle the case where the file is not found
    print("The file 'example.txt' was not found in the specified directory.")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#  20210122_173847.jpg
#  20210122_174210.jpg
#  20210122_175450.jpg
#  20210122_175542.jpg
# '202404222331 (1).mp4'
#  202404222331.mp4
#  202404222334.mp4
#  202404222344.mp4
# '202404222351 (1).mp4'
#  202404222351.mp4
#  202404222354.mp4
# '202404222357 (1).mp4'
# '202404222357 (2).mp4'
#  202404222357.mp4
# '202404230736 (1).mp4'
# '202404230736 (2).mp4'
#  202404230736.mp4
#  202404230747.mp4
# '202404230749 (1).mp4'
#  202404230749.mp4
# '202404230755 (2).mp4'
#  202404230755.mp4
# '203002051_os lab final.gdoc'
#  203002051.pdf
#  212015043.ipynb
# '221 D3_203002051_Israt_Class tuch1.gdoc'
#  315439971_635393421570634_8802112068056636167_n.jpg
#  349339427_639700024688548_3616750264058841968_n.jpg
#  4e46cf01-9824-41e9-9f9f-b9b7fdec13b2.jpeg
# 'Accounting Principle Weygandt Kieso Kimmel 9e (1).gdoc'
# 'Admin Moderator Information (File responses)'
# ...

# %%
#File RD
p= "/content/drive/My Drive/PyP_(Batch-8)_Israt/Israt.txt"

with open (p, 'r') as file :
 content = file . read ()
 print ( content )
# Out:
# Hello Israt

# %%
#file RW
p= "/content/drive/My Drive/PyP_(Batch-8)_Israt/Israt.txt"

with open (p, 'w') as file :
  file.write ('Hello , World !\n')


with open (p, 'r') as file :
 content = file . read ()
 print ( content )
# Out:
# Hello , World !

# %%
p= "/content/drive/My Drive/PyP_(Batch-8)_Israt/Israt.txt"

with open (p, 'r') as file :
 content = file . read ()
 print ( content )
# Out:
# Hello , World !

# %%
p1= "/content/drive/My Drive/PyP_(Batch-8)_Israt/Isratt.txt"
with open (p1, 'w') as file :
  file.write (content)

with open (p1, 'r') as file :
 content1 = file . read ()
 print ( content1 )
# Out:
# Hello , World !

# %%
p1= "/content/drive/My Drive/PyP_(Batch-8)_Israt/Isratt.txt"
with open (p1, 'a') as file :
  file.write (content)

with open (p1, 'r') as file :
 content5 = file . read ()
 print ( content5 )
# Out:
# Hello , World !
# Hello , World !
# Hello , World !
